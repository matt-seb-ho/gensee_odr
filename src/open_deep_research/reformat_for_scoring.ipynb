# %%
import json
from pathlib import Path

# %%
# /home/matt/dere/gensee_odr/outputs/drb_g25_tav.json \
# /home/matt/dere/gensee_odr/outputs/drb_g25_gen.json \
# /home/matt/dere/gensee_odr/outputs/drb_g3_tav.json \
# /home/matt/dere/gensee_odr/outputs/drb_g3_gen.json

OUTPUT_DIR = Path("/home/matt/dere/gensee_odr/outputs")
target_files = [
    OUTPUT_DIR / "drb_g25_tav.json",
    OUTPUT_DIR / "drb_g25_gen.json",
    OUTPUT_DIR / "drb_g3_tav.json",
    OUTPUT_DIR / "drb_g3_gen.json",
]

# %%
f0 = json.loads(target_files[0].read_text())

# %%
# Score locally generated Deep Research reports against DeepResearch-Bench references.

# Input: a JSON file with either:
#   A) {"prompt1": "your article string", "prompt2": "...", ...}
#   B) [{"prompt": "...", "article": "..."}, ...]
# Optional: query.jsonl to infer per-prompt language (en/zh). If absent, defaults to --language or 'en'.

# %%
SCORE_FILE_DIR = OUTPUT_DIR / "scoring_files"
SCORE_FILE_DIR.mkdir(exist_ok=True, parents=True)
scoring_files = [
    tgt_file.parent / "scoring_files" / tgt_file.name for tgt_file in target_files
]

# %%
print(f0["69"]["final_report"])
# Out:
# # A Comparative Analysis of Google's A2A and MCP Protocols
#
# This report provides a detailed explanation of Google's Automotive-to-Accessory (A2A) protocol and the Mobile Carrier Plan (MCP) protocol. It analyzes their differences and connections, elaborates on the innovative aspects of the A2A protocol, and details the specific problems it is designed to address, based on available technical documentation.
#
# ## 1. Definitions
#
# To establish a clear foundation for comparison, this section defines the two protocols and the key technical terms necessary for their understanding.
#
# ### Google's A2A (Automotive-to-Accessory) Protocol
#
# The A2A protocol is an application-layer protocol developed by Google for the Android Automotive OS ecosystem. Its primary function is to facilitate robust, high-throughput, and low-latency communication between an Android Automotive head unit (the in-car infotainment system) and accessory devices, such as a user's mobile phone. It is designed to operate over modern peer-to-peer wireless transports like Wi-Fi Aware and Wi-Fi Direct, enabling advanced features like high-fidelity audio and video streaming that are not well-supported by traditional protocols like Bluetooth [1]. The protocol manages service discovery, session establishment, security, and data exchange, abstracting the complexity of the underlying network transport from the application developer.
#
# ### MCP (Mobile Carrier Plan) Protocol
#
# In the context of Google's technologies, the most relevant "MCP protocol" is the **Mobile Carrier Plan** protocol. This selection is justified because Google was a primary developer of this protocol in collaboration with the GSMA to standardize how mobile applications interact with carrier infrastructure [2]. It is an application-layer, client-server protocol designed to allow mobile applications to directly and securely query a user's mobile data plan information from their carrier. This enables features such as displaying remaining data, plan renewal dates, and managing data usage directly within an application or the operating system's settings, eliminating the need for users to visit a carrier's website or use a specific carrier app [3].
#
# ### Key Technical Terms
#
# *   **Data Serialization:** The process of converting complex data structures (like objects or data trees) into a format (like a byte stream, JSON, or XML) that can be easily stored, transmitted across a network, and reconstructed later. This is crucial for interoperability between different systems.
# *   **Session Management:** The set of procedures for establishing, maintaining, and terminating a communication link, or "session," between two endpoints. This includes handling connection state, authentication, and graceful disconnection.
# *   **Security Model:** A framework that dictates how security is implemented within a system or protocol. It defines the rules for authentication (proving identity), authorization (granting permissions), confidentiality (encryption), and data integrity (preventing tampering).
# *   **Peer-to-Peer (P2P) Architecture:** A network architecture where participants (peers) communicate directly with each other without the need for a central server. This model is characterized by decentralization and direct device-to-device links.
# *   **Client-Server Architecture:** A network architecture where one program (the client) requests services or resources from another program (the server). This is a centralized model common for web services and internet applications.
# *   **Wi-Fi Aware (Neighbor Awareness Networking - NAN):** A Wi-Fi Alliance certification program that enables Wi-Fi devices to discover each other and exchange information before establishing a network connection, all without requiring a traditional Wi-Fi access point (AP) [4]. It is highly efficient for proximity-based service discovery.
#
# ## 2. Analysis of the Protocols
#
# This section delves into the core objectives, technical specifications, and innovative elements of the A2A and MCP protocols.
#
# ### Conceptual Foundations
#
# The two protocols are founded on entirely different objectives and architectural principles, tailored to their specific problem domains.
#
# *   **A2A Protocol:**
#     *   **Core Objective:** To create a seamless, high-performance, and secure "wired-like" experience over a wireless connection for in-vehicle connectivity. The goal is to overcome the limitations of existing standards like Bluetooth for rich media applications.
#     *   **Functionality:** A2A handles device discovery, secure pairing, session negotiation, and multiplexing of multiple data streams over a single connection. It is designed to support high-bandwidth applications such as projecting a phone's user interface, streaming video to rear-seat entertainment systems, or high-fidelity audio playback [1].
#     *   **Architectural Principles:** A2A is built on a **peer-to-peer (P2P)** architecture. It leverages modern, local-area wireless technologies like Wi-Fi Aware for energy-efficient discovery and Wi-Fi Direct or a standard Wi-Fi infrastructure connection for high-speed data transfer. This avoids reliance on a central server or internet connectivity for its core functions.
#
# *   **MCP Protocol:**
#     *   **Core Objective:** To standardize the communication between mobile devices and carrier networks for data plan management. The goal is to provide a consistent and secure API for any authorized application to access carrier-specific information on behalf of the user.
#     *   **Functionality:** The protocol defines a set of API endpoints for querying data plan status (e.g., data allowance, usage, expiration), viewing offers, and potentially purchasing data top-ups. It provides a structured data format, typically JSON, for these interactions [3].
#     *   **Architectural Principles:** MCP follows a classic **client-server** architecture. The mobile device or application acts as the client, making HTTPS requests to a server endpoint hosted by the mobile network operator (MNO). This interaction relies on existing internet infrastructure (cellular or Wi-Fi) and standard web security protocols.
#
# ### Comparative Analysis
#
# The technical differences between A2A and MCP are stark, reflecting their divergent purposes.
#
# | Feature               | A2A (Automotive-to-Accessory) Protocol                                | MCP (Mobile Carrier Plan) Protocol                                     |
# | --------------------- | --------------------------------------------------------------------- | ---------------------------------------------------------------------- |
# | **Primary Use Case**  | High-performance, in-vehicle connectivity (e.g., media streaming, app projection). | Remote management and querying of mobile data plans.                   |
# | **Architecture**      | Peer-to-Peer (P2P). Devices communicate directly.                     | Client-Server. The device (client) queries the carrier's server.       |
# | **Network Scope**     | Local Area Network (LAN). Operates within the physical proximity of a vehicle. | Wide Area Network (WAN). Relies on internet connectivity to reach carrier servers. |
# | **Transport Layer**   | Wi-Fi Aware (for discovery), Wi-Fi Direct / Wi-Fi (for data transfer). | TCP/IP, typically over HTTPS (HTTP over TLS).                          |
# | **Data Handling**     | Optimized for low latency and high throughput. Likely uses a binary serialization format like Protocol Buffers for efficiency [1]. | Optimized for web compatibility and human readability. Uses JSON over HTTPS [3]. |
# | **Security Model**    | Proximity-based trust and pairing. Relies on user confirmation and transport-level encryption (e.g., WPA3). | Based on standard web security. Uses TLS for channel encryption and OAuth 2.0 for user authorization to grant apps access to their plan data [2]. |
# | **Session Management**| Manages a persistent, stateful connection between the head unit and accessory. | Typically stateless. Each API request is an independent, atomic transaction. |
#
# ### Innovation of the A2A Protocol
#
# The primary innovation of the A2A protocol lies in its synthesis and standardization of modern technologies to solve a specific, high-value problem.
#
# 1.  **Leveraging Wi-Fi Aware for Seamless Discovery:** Unlike traditional Wi-Fi that requires connecting to an access point or Bluetooth that involves a clunky pairing process, A2A's use of Wi-Fi Aware allows for continuous, low-power, and zero-configuration discovery of compatible devices in the vicinity [4]. A phone can discover and identify the car's head unit as an A2A-capable device automatically upon entering the vehicle.
# 2.  **Abstracting Transport Complexity:** A2A provides a stable application-layer protocol on top of multiple, complex underlying transports (Wi-Fi Aware, Wi-Fi Direct). This allows application developers to focus on the features of their app (e.g., a media player) without needing to manage the intricacies of P2P network setup, link negotiation, or security handshakes.
# 3.  **High-Performance Wireless Experience:** By standardizing a protocol designed for high-throughput and low-latency, A2A enables experiences that were previously only possible with a wired connection (like USB-based Android Auto) or were unreliable over Bluetooth. This is crucial for next-generation in-car infotainment, such as 4K video streaming or responsive interactive projections.
# 4.  **Standardization over Proprietary Solutions:** Before A2A, car manufacturers and device makers often relied on proprietary protocols for advanced connectivity. A2A creates an open, standardized ecosystem within Android Automotive, promoting interoperability and reducing development fragmentation.
#
# ### Problem Domain Addressed by A2A
#
# The A2A protocol is specifically designed to solve the limitations of existing wireless protocols in the demanding automotive environment.
#
# *   **Bluetooth Bandwidth and Latency:** Standard Bluetooth profiles (like A2DP for audio) lack the bandwidth for high-resolution video or multichannel, high-fidelity audio. The latency can also be prohibitive for interactive applications like screen mirroring or gaming.
# *   **Wi-Fi Setup Complexity:** While traditional Wi-Fi has sufficient bandwidth, it typically requires manual setup: the user must find the car's Wi-Fi network (SSID), enter a password, and manage the connection. This creates friction and is not a seamless "just-works" experience expected in a modern vehicle.
# *   **Lack of a Unified Protocol:** Without a standard like A2A, developers would have to contend with a fragmented landscape of proprietary solutions from different automotive OEMs. A2A provides a single, consistent target for developing rich, connected in-car experiences on Android Automotive OS.
#
# ### Interconnection Between A2A and MCP
#
# There are **no direct technical connections** between the A2A and MCP protocols. They are independent solutions developed by Google for entirely separate domains.
#
# *   **A2A does not replace MCP.** A2A is for local device communication, while MCP is for remote communication with a carrier. A vehicle with A2A could theoretically also use an application that implements MCP to check its embedded SIM's data plan, but the two protocols would not interact.
# *   **A2A does not complement MCP.** Their functionalities are orthogonal. One manages local media and data streams, while the other manages billing and data quota information over the internet.
# *   **A2A does not build upon concepts from MCP.** A2A's P2P architecture, reliance on Wi-Fi Aware, and focus on low-latency streaming are fundamentally different from MCP's web-based, client-server, request-response model.
#
# In summary, A2A and MCP are two distinct protocols from Google's portfolio, each tailored to solve a unique set of problems in different technological ecosystems—automotive and telecommunications, respectively.
#
# ## Sources
#
# [1] Google Git - Android Open Source Project, A2A Protocol Documentation. [https://android.googlesource.com/platform/packages/services/Car/+/refs/heads/main/service/src/com/android/car/a2a/](https://android.googlesource.com/platform/packages/services/Car/+/refs/heads/main/service/src/com/android/car/a2a/)
#
# [2] GSMA Official Documentation, Mobile Carrier Plan Framework. [https://www.gsma.com/identity/resources/mobile-carrier-plan-framework](https://www.gsma.com/identity/resources/mobile-carrier-plan-framework)
#
# [3] Google Developers Blog, "Helping users manage their mobile data in Android." [https://android-developers.googleblog.com/2016/09/helping-users-manage-their-mobile-data.html](https://android-developers.googleblog.com/2016/09/helping-users-manage-their-mobile-data.html)
#
# [4] Wi-Fi Alliance, "Wi-Fi CERTIFIED Wi-Fi Aware™." [https://www.wi-fi.org/discover-wi-fi/wi-fi-aware](https://www.wi-fi.org/discover-wi-fi/wi-fi-aware)

# %%
for tgt_file, score_file in zip(target_files, scoring_files):
    data = json.loads(tgt_file.read_text())
    # entries = []
    entry_dict = {}
    for prompt_id, info in data.items():
        prompt = info["prompt"]
        article = info["final_report"]
        # score_entry = {"prompt": prompt, "article": article}
        # entries.append(score_entry)
        entry_dict[prompt] = article
    # score_file.write_text(json.dumps(entries, indent=2, ensure_ascii=False))
    score_file.write_text(json.dumps(entry_dict, indent=2, ensure_ascii=False))
    print(f"Wrote {len(entry_dict)} entries to {score_file}")
# Out:
# Wrote 3 entries to /home/matt/dere/gensee_odr/outputs/scoring_files/drb_g25_tav.json
# Wrote 3 entries to /home/matt/dere/gensee_odr/outputs/scoring_files/drb_g25_gen.json
# Wrote 3 entries to /home/matt/dere/gensee_odr/outputs/scoring_files/drb_g3_tav.json
# Wrote 3 entries to /home/matt/dere/gensee_odr/outputs/scoring_files/drb_g3_gen.json

# %%
for score_file in scoring_files:
    print(score_file)
# Out:
# /home/matt/dere/gensee_odr/outputs/scoring_files/drb_g25_tav.json
# /home/matt/dere/gensee_odr/outputs/scoring_files/drb_g25_gen.json
# /home/matt/dere/gensee_odr/outputs/scoring_files/drb_g3_tav.json
# /home/matt/dere/gensee_odr/outputs/scoring_files/drb_g3_gen.json

# %% [markdown]
# # reformat into jsonl
#
# ```
# {
#   "response": "Your model's generated survey text here...",
#   "arxiv_id": "2024.12345",  // Optional: will be extracted from filename if not present
#   "query": "Original query prompt",  // Optional
#   // ... other metadata fields
# }
# ```

# %%
report_bench_files = [
    OUTPUT_DIR / "rb_g25_tav.json",
    OUTPUT_DIR / "rb_g25_gen.json",
    OUTPUT_DIR / "rb_g3_tav.json",
    OUTPUT_DIR / "rb_g3_gen.json",
]

# %%
dummy = json.loads(report_bench_files[0].read_text())

# %%
dummy.keys()
# Out:
# dict_keys(['2011.13534', '2206.05498', '2207.14394'])

# %%
dummy["2011.13534"].keys()
# Out:
# dict_keys(['prompt', 'final_report', 'total_cost_usd', 'total_prompt_tokens', 'total_completion_tokens', 'spans', 'raw_events'])

# %%
# {
#   "response": "Your model's generated survey text here...",
#   "arxiv_id": "2024.12345",  // Optional: will be extracted from filename if not present
#   "query": "Original query prompt",  // Optional
#   // ... other metadata fields
# }
jsonl_files = []
for rbf in report_bench_files:
    data = json.loads(rbf.read_text())
    jsonl_path = rbf.with_suffix(".jsonl")
    with jsonl_path.open("w") as f:
        for arxiv_id, item in data.items():
            entry = {
                "response": item["final_report"],
                "arxiv_id": arxiv_id,
                "query": item.get("prompt", ""),
            }
            f.write(json.dumps(entry) + "\n")
        print(f"Wrote {jsonl_path}")
    jsonl_files.append(jsonl_path)
# Out:
# Wrote /home/matt/dere/gensee_odr/outputs/rb_g25_tav.jsonl
# Wrote /home/matt/dere/gensee_odr/outputs/rb_g25_gen.jsonl
# Wrote /home/matt/dere/gensee_odr/outputs/rb_g3_tav.jsonl
# Wrote /home/matt/dere/gensee_odr/outputs/rb_g3_gen.jsonl
